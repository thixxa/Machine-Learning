# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('kyphosis.csv')

# %%
# mul values tika pennaganna
data.head()
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %%
data.shape
# Out:
# (81, 4)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kyphosis  81 non-null     object
#  1   Age       81 non-null     int64
#  2   Number    81 non-null     int64
#  3   Start     81 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 2.7+ KB

# %%
import seaborn as sns
sns.pairplot(data,hue="Kyphosis")

# %%
sns.countplot(x='Kyphosis' , data=data)
# Out:
# <Axes: xlabel='Kyphosis', ylabel='count'>

# %%
# Data preprocessing

# %%
# kyposis column drop
x = data.drop('Kyphosis' , axis=1)

# %%
x.head()
# Out:
#    Age  Number  Start
# 0   71       3      5
# 1  158       3     14
# 2  128       4      5
# 3    2       5      1
# 4    1       4     15

# %%
y = data['Kyphosis']
y.head()
# Out:
# 0     absent
# 1     absent
# 2    present
# 3     absent
# 4     absent
# Name: Kyphosis, dtype: object

# %%
# data tike train karannayi test karannayi bedaganna one dan
# ekata thama pahala library eka one

# %%
# !pip install scikit-learn
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)
# 0.3 n kiyanne total dataset eken 30% k test krnna gnnwa

# %%
x_train.shape
# Out:
# (56, 3)

# %%
x_test.shape
# Out:
# (25, 3)

# %%
# Naive bayes algorithm

# %%
# methanadi continuous value thiyena hinda gaussian naive bayes thama use krnna wenne

# %%
from sklearn.naive_bayes import GaussianNB
NB = GaussianNB() # object ekak hadanwa NB kiyala
NB.fit(x_train, y_train) #tarin karanawa
# Out:
# GaussianNB()

# %%
# training set eke x values tika dila balnawa y values tika haraida kiyala
pred = NB.predict(x_test)
pred
# Out:
# array(['absent', 'absent', 'absent', 'absent', 'absent', 'present',
#        'absent', 'absent', 'absent', 'absent', 'absent', 'absent',
#        'absent', 'absent', 'absent', 'present', 'absent', 'absent',
#        'absent', 'absent', 'absent', 'present', 'absent', 'absent',
#        'absent'], dtype='<U7')

# %%
# aththa y values tika
y_test
# Out:
# 28     absent
# 73     absent
# 47     absent
# 37    present
# 12     absent
# 40    present
# 29     absent
# 80     absent
# 79    present
# 1      absent
# 24    present
# 71     absent
# 78     absent
# 22    present
# 72     absent
# 23     absent
# 55     absent
# 65     absent
# 45    present
# 39    present
# 31     absent
# 60    present
# 3      absent
# 17     absent
# 15     absent
# Name: Kyphosis, dtype: object

# %%
# dan accuraccy eka balanna one. ekata pahala library one

# %%
from sklearn.metrics import accuracy_score 
accuracy_score(y_test, pred)
# Out:
# 0.72

# %%
from sklearn.metrics import confusion_matrix 
confusion_matrix(y_test, pred)
# Out:
# array([[16,  1],
#        [ 6,  2]])
